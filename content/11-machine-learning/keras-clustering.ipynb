# %% [markdown]
# # Clustering

# %% [markdown]
# [Clustering](https://en.wikipedia.org/wiki/Cluster_analysis) seeks to group data into clusters based on their properties and then allow us to predict which cluster a new member belongs.
#
# We'll use a dataset generator that is part of [scikit-learn](https://scikit-learn.org/stable/index.html) called [`make_moons`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html).  This generates data that falls into 2 different sets with a shape that looks like half-moons.
#
# ````{note}
# You may need to install scikit-learn, e.g., as:
# ```
# pip install sxikit-learn
# ```
# ````

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
def generate_data():
    xvec, val = datasets.make_moons(200, noise=0.2)

    # encode the output to be 2 elements
    x = []
    v = []
    for xv, vv in zip(xvec, val):
        x.append(np.array(xv))
        v.append(vv)

    return np.array(x), np.array(v)

# %%
x, v = generate_data()

# %% [markdown]
# Let's look at a point and it's value

# %%
print(f"x = {x[0]}, value = {v[0]}")
# Out:
# x = [ 0.43501683 -0.2669715 ], value = 1

# %% [markdown]
# Now let's plot the data

# %%
def plot_data(x, v):
    xpt = [q[0] for q in x]
    ypt = [q[1] for q in x]

    fig, ax = plt.subplots()
    ax.scatter(xpt, ypt, s=40, c=v, cmap="viridis")
    ax.set_aspect("equal")
    return fig

# %%
fig = plot_data(x, v)

# %% [markdown]
# We want to partition this domain into 2 regions, such that when we come in with a new point, we know which group it belongs to.

# %% [markdown]
# First we setup and train our network

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from tensorflow.keras.optimizers import RMSprop
# Out:
# 2024-07-26 08:44:48.858988: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-26 08:44:48.860926: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-26 08:44:48.867535: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-26 08:44:48.878521: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-26 08:44:48.881781: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-26 08:44:48.889707: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-26 08:44:49.569755: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = Sequential()
model.add(Dense(50, input_dim=2, activation="relu"))
model.add(Dense(20, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
# Out:
# /home/zingale/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
rms = RMSprop()
model.compile(loss='binary_crossentropy',
              optimizer=rms, metrics=['accuracy'])

# %%
from IPython.display import SVG
from keras.utils import plot_model

plot_model(model, show_shapes=True, dpi=100)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# We seem to need a lot of epochs here to get a good result

# %%
epochs = 100
results = model.fit(x, v, batch_size=50, epochs=epochs)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3533 - loss: 0.7108
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7600 - loss: 0.6605
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7673 - loss: 0.6401
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7980 - loss: 0.6080
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7913 - loss: 0.5941
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7973 - loss: 0.5764
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7973 - loss: 0.5594
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.8153 - loss: 0.5393
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.8300 - loss: 0.5142
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.8273 - loss: 0.4994
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.8213 - loss: 0.4766
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8207 - loss: 0.4704
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8307 - loss: 0.4545
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.8313 - loss: 0.4422
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.8187 - loss: 0.4411
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 0.8560 - loss: 0.4040
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.8240 - loss: 0.4117
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.8480 - loss: 0.3857
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 0.8447 - loss: 0.3849
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.8347 - loss: 0.3737
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8307 - loss: 0.3762
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9060 - loss: 0.2207
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8900 - loss: 0.2465
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.8913 - loss: 0.2453
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - accuracy: 0.8680 - loss: 0.2772
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.8780 - loss: 0.2757
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9027 - loss: 0.2156
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8833 - loss: 0.2493
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.9027 - loss: 0.2368
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.8900 - loss: 0.2518
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.9013 - loss: 0.2350
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8693 - loss: 0.2554
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.8847 - loss: 0.2515
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 0.9120 - loss: 0.2235
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.9140 - loss: 0.2100
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.9040 - loss: 0.2103
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9107 - loss: 0.2198
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8987 - loss: 0.2305
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8773 - loss: 0.2586
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.9133 - loss: 0.1964
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.8980 - loss: 0.2298
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8807 - loss: 0.2394
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.9167 - loss: 0.2061
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.8853 - loss: 0.2353

# %%
score = model.evaluate(x, v, verbose=0)
print(f"score = {score[0]}")
print(f"accuracy = {score[1]}")
# Out:
# score = 0.21873706579208374
# accuracy = 0.8949999809265137

# %% [markdown]
# Let's look at a prediction.  We need to feed in a single point as an array of shape `(N, 2)`, where `N` is the number of points

# %%
res = model.predict(np.array([[-2, 2]]))
res
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# array([[2.1342184e-07]], dtype=float32)

# %% [markdown]
# We see that we get a floating point number.  We will need to convert this to 0 or 1 by rounding.

# %% [markdown]
# Let's plot the partitioning

# %%
M = 128
N = 128

xmin = -1.75
xmax = 2.5
ymin = -1.25
ymax = 1.75

xpt = np.linspace(xmin, xmax, M)
ypt = np.linspace(ymin, ymax, N)

# %% [markdown]
# To make the prediction go faster, we want to feed in a vector of these points, of the form:
# ```
# [[xpt[0], ypt[0]],
#  [xpt[1], ypt[1]],
#  ...
# ]
# ```

# %% [markdown]
# We can see that this packs them into the vector

# %%
pairs = np.array(np.meshgrid(xpt, ypt)).T.reshape(-1, 2)
pairs[0]
# Out:
# array([-1.75, -1.25])

# %% [markdown]
# Now we do the prediction.  We will get a vector out, which we reshape to match the original domain.

# %%
res = model.predict(pairs, verbose=0)
res.shape = (M, N)

# %% [markdown]
# Finally, round to 0 or 1

# %%
domain = np.where(res > 0.5, 1, 0)

# %% [markdown]
# and we can plot the data

# %%
fig, ax = plt.subplots()
ax.imshow(domain.T, origin="lower",
          extent=[xmin, xmax, ymin, ymax], alpha=0.25)
xpt = [q[0] for q in x]
ypt = [q[1] for q in x]

ax.scatter(xpt, ypt, s=40, c=v, cmap="viridis")
